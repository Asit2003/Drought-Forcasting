# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = read_csv('wavelet_coefficients_coif4.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [1,2,3]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
dataset
# Out:
#                  Approximation       D 1       D 2       D 3       D 4
# Original Signal
# -1.54                -0.399407  0.123789  0.432821  0.909784  0.075686
# -1.54                -0.335692 -0.029598  0.153191  0.303381  0.150012
# -1.20                -0.265293  0.079268 -0.233209 -0.312290  0.215815
#  0.15                -0.189437 -0.014952 -0.530351 -0.712687  0.266250
#  1.20                -0.109111 -0.076102 -0.507691 -0.819493  0.293859
# ...                        ...       ...       ...       ...       ...
#  1.18                -0.583669  0.080912 -0.531384 -0.581161 -0.221588
#  1.75                -0.565725 -0.075091 -0.615182 -0.037365 -0.183377
#  1.79                -0.538686  0.298867 -0.235284  0.622934 -0.133964
#  1.49                -0.501871 -0.143427  0.224154  1.126316 -0.071878
#  0.83                -0.455194 -0.178441  0.472532  1.237173 -0.000182
#
# [490 rows x 5 columns]

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# load dataset
dataset = read_csv('wavelet_coefficients_coif4.csv')
dataset=dataset.drop(['Approximation', 'D 4'], axis=1)

# %%
dataset
# Out:
#      Original Signal       D 1       D 2       D 3
# 0              -1.54  0.123789  0.432821  0.909784
# 1              -1.54 -0.029598  0.153191  0.303381
# 2              -1.20  0.079268 -0.233209 -0.312290
# 3               0.15 -0.014952 -0.530351 -0.712687
# 4               1.20 -0.076102 -0.507691 -0.819493
# ..               ...       ...       ...       ...
# 485             1.18  0.080912 -0.531384 -0.581161
# 486             1.75 -0.075091 -0.615182 -0.037365
# 487             1.79  0.298867 -0.235284  0.622934
# 488             1.49 -0.143427  0.224154  1.126316
# 489             0.83 -0.178441  0.472532  1.237173
#
# [490 rows x 4 columns]

# %%
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,3] = encoder.fit_transform(values[:,3])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed)
# drop columns we don't want to predict
# reframed.drop(reframed.columns[[2,3,6]], axis=1, inplace=True)
# print(reframed.head())
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)   var2(t)   var3(t)  \
# 1     0.252632   0.447295   0.608254   0.903885  0.252632  0.359785  0.515232
# 2     0.252632   0.359785   0.515232   0.670757  0.303759  0.421895  0.386691
# 3     0.303759   0.421895   0.386691   0.325153  0.506767  0.368141  0.287843
# 4     0.506767   0.368141   0.287843   0.159509  0.664662  0.333254  0.295381
# 5     0.664662   0.333254   0.295381   0.139059  0.664662  0.450760  0.452611
# ..         ...        ...        ...        ...       ...       ...       ...
# 485   0.586466   0.254410   0.485733   0.120654  0.661654  0.422833  0.287500
# 486   0.661654   0.422833   0.287500   0.192229  0.747368  0.333831  0.259623
# 487   0.747368   0.333831   0.259623   0.484663  0.753383  0.547179  0.386001
# 488   0.753383   0.547179   0.386001   0.824131  0.708271  0.294844  0.538839
# 489   0.708271   0.294844   0.538839   0.944785  0.609023  0.274868  0.621465
#
#       var4(t)
# 1    0.670757
# 2    0.325153
# 3    0.159509
# 4    0.139059
# 5    0.173824
# ..        ...
# 485  0.192229
# 486  0.484663
# 487  0.824131
# 488  0.944785
# 489  0.957055
#
# [489 rows x 8 columns]

# %%
reframed
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)   var2(t)   var3(t)  \
# 1     0.252632   0.447295   0.608254   0.903885  0.252632  0.359785  0.515232
# 2     0.252632   0.359785   0.515232   0.670757  0.303759  0.421895  0.386691
# 3     0.303759   0.421895   0.386691   0.325153  0.506767  0.368141  0.287843
# 4     0.506767   0.368141   0.287843   0.159509  0.664662  0.333254  0.295381
# 5     0.664662   0.333254   0.295381   0.139059  0.664662  0.450760  0.452611
# ..         ...        ...        ...        ...       ...       ...       ...
# 485   0.586466   0.254410   0.485733   0.120654  0.661654  0.422833  0.287500
# 486   0.661654   0.422833   0.287500   0.192229  0.747368  0.333831  0.259623
# 487   0.747368   0.333831   0.259623   0.484663  0.753383  0.547179  0.386001
# 488   0.753383   0.547179   0.386001   0.824131  0.708271  0.294844  0.538839
# 489   0.708271   0.294844   0.538839   0.944785  0.609023  0.274868  0.621465
#
#       var4(t)
# 1    0.670757
# 2    0.325153
# 3    0.159509
# 4    0.139059
# 5    0.173824
# ..        ...
# 485  0.192229
# 486  0.484663
# 487  0.824131
# 488  0.944785
# 489  0.957055
#
# [489 rows x 8 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 392
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (392, 1, 7) (392,) (97, 1, 7) (97,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=120, batch_size=64, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/120
# 7/7 - 2s - loss: 0.4566 - val_loss: 0.4119 - 2s/epoch - 279ms/step
# Epoch 2/120
# 7/7 - 0s - loss: 0.3929 - val_loss: 0.3531 - 41ms/epoch - 6ms/step
# Epoch 3/120
# 7/7 - 0s - loss: 0.3382 - val_loss: 0.3130 - 38ms/epoch - 5ms/step
# Epoch 4/120
# 7/7 - 0s - loss: 0.2915 - val_loss: 0.2831 - 43ms/epoch - 6ms/step
# Epoch 5/120
# 7/7 - 0s - loss: 0.2551 - val_loss: 0.2637 - 43ms/epoch - 6ms/step
# Epoch 6/120
# 7/7 - 0s - loss: 0.2319 - val_loss: 0.2511 - 36ms/epoch - 5ms/step
# Epoch 7/120
# 7/7 - 0s - loss: 0.2172 - val_loss: 0.2457 - 40ms/epoch - 6ms/step
# Epoch 8/120
# 7/7 - 0s - loss: 0.2103 - val_loss: 0.2436 - 41ms/epoch - 6ms/step
# Epoch 9/120
# 7/7 - 0s - loss: 0.2077 - val_loss: 0.2408 - 38ms/epoch - 5ms/step
# Epoch 10/120
# 7/7 - 0s - loss: 0.2050 - val_loss: 0.2369 - 35ms/epoch - 5ms/step
# Epoch 11/120
# 7/7 - 0s - loss: 0.2023 - val_loss: 0.2331 - 36ms/epoch - 5ms/step
# Epoch 12/120
# 7/7 - 0s - loss: 0.1995 - val_loss: 0.2295 - 41ms/epoch - 6ms/step
# Epoch 13/120
# 7/7 - 0s - loss: 0.1966 - val_loss: 0.2259 - 39ms/epoch - 6ms/step
# Epoch 14/120
# 7/7 - 0s - loss: 0.1935 - val_loss: 0.2222 - 38ms/epoch - 5ms/step
# Epoch 15/120
# 7/7 - 0s - loss: 0.1902 - val_loss: 0.2184 - 44ms/epoch - 6ms/step
# Epoch 16/120
# 7/7 - 0s - loss: 0.1868 - val_loss: 0.2146 - 41ms/epoch - 6ms/step
# Epoch 17/120
# 7/7 - 0s - loss: 0.1834 - val_loss: 0.2108 - 43ms/epoch - 6ms/step
# Epoch 18/120
# 7/7 - 0s - loss: 0.1801 - val_loss: 0.2069 - 39ms/epoch - 6ms/step
# Epoch 19/120
# 7/7 - 0s - loss: 0.1767 - val_loss: 0.2028 - 36ms/epoch - 5ms/step
# Epoch 20/120
# 7/7 - 0s - loss: 0.1731 - val_loss: 0.1985 - 39ms/epoch - 6ms/step
# Epoch 21/120
# 7/7 - 0s - loss: 0.1695 - val_loss: 0.1941 - 37ms/epoch - 5ms/step
# Epoch 22/120
# 7/7 - 0s - loss: 0.1657 - val_loss: 0.1894 - 40ms/epoch - 6ms/step
# Epoch 23/120
# 7/7 - 0s - loss: 0.1617 - val_loss: 0.1847 - 39ms/epoch - 6ms/step
# Epoch 24/120
# 7/7 - 0s - loss: 0.1575 - val_loss: 0.1796 - 43ms/epoch - 6ms/step
# Epoch 25/120
# 7/7 - 0s - loss: 0.1534 - val_loss: 0.1745 - 38ms/epoch - 5ms/step
# Epoch 26/120
# 7/7 - 0s - loss: 0.1492 - val_loss: 0.1692 - 39ms/epoch - 6ms/step
# Epoch 27/120
# 7/7 - 0s - loss: 0.1449 - val_loss: 0.1633 - 40ms/epoch - 6ms/step
# Epoch 28/120
# 7/7 - 0s - loss: 0.1406 - val_loss: 0.1574 - 40ms/epoch - 6ms/step
# Epoch 29/120
# 7/7 - 0s - loss: 0.1365 - val_loss: 0.1525 - 41ms/epoch - 6ms/step
# Epoch 30/120
# 7/7 - 0s - loss: 0.1331 - val_loss: 0.1478 - 42ms/epoch - 6ms/step
# Epoch 31/120
# 7/7 - 0s - loss: 0.1303 - val_loss: 0.1434 - 41ms/epoch - 6ms/step
# Epoch 32/120
# 7/7 - 0s - loss: 0.1278 - val_loss: 0.1400 - 46ms/epoch - 7ms/step
# Epoch 33/120
# 7/7 - 0s - loss: 0.1257 - val_loss: 0.1372 - 45ms/epoch - 6ms/step
# Epoch 34/120
# 7/7 - 0s - loss: 0.1239 - val_loss: 0.1351 - 37ms/epoch - 5ms/step
# Epoch 35/120
# 7/7 - 0s - loss: 0.1227 - val_loss: 0.1341 - 37ms/epoch - 5ms/step
# Epoch 36/120
# 7/7 - 0s - loss: 0.1221 - val_loss: 0.1334 - 37ms/epoch - 5ms/step
# Epoch 37/120
# 7/7 - 0s - loss: 0.1216 - val_loss: 0.1330 - 38ms/epoch - 5ms/step
# Epoch 38/120
# 7/7 - 0s - loss: 0.1213 - val_loss: 0.1327 - 38ms/epoch - 5ms/step
# Epoch 39/120
# 7/7 - 0s - loss: 0.1211 - val_loss: 0.1326 - 42ms/epoch - 6ms/step
# Epoch 40/120
# 7/7 - 0s - loss: 0.1209 - val_loss: 0.1325 - 38ms/epoch - 5ms/step
# Epoch 41/120
# 7/7 - 0s - loss: 0.1206 - val_loss: 0.1324 - 38ms/epoch - 5ms/step
# Epoch 42/120
# 7/7 - 0s - loss: 0.1205 - val_loss: 0.1325 - 39ms/epoch - 6ms/step
# Epoch 43/120
# 7/7 - 0s - loss: 0.1203 - val_loss: 0.1323 - 40ms/epoch - 6ms/step
# Epoch 44/120
# 7/7 - 0s - loss: 0.1201 - val_loss: 0.1324 - 38ms/epoch - 5ms/step
# Epoch 45/120
# 7/7 - 0s - loss: 0.1200 - val_loss: 0.1323 - 41ms/epoch - 6ms/step
# Epoch 46/120
# 7/7 - 0s - loss: 0.1198 - val_loss: 0.1322 - 39ms/epoch - 6ms/step
# Epoch 47/120
# 7/7 - 0s - loss: 0.1198 - val_loss: 0.1322 - 42ms/epoch - 6ms/step
# Epoch 48/120
# 7/7 - 0s - loss: 0.1197 - val_loss: 0.1321 - 44ms/epoch - 6ms/step
# Epoch 49/120
# 7/7 - 0s - loss: 0.1196 - val_loss: 0.1321 - 46ms/epoch - 7ms/step
# Epoch 50/120
# 7/7 - 0s - loss: 0.1195 - val_loss: 0.1319 - 41ms/epoch - 6ms/step
# Epoch 51/120
# 7/7 - 0s - loss: 0.1195 - val_loss: 0.1319 - 36ms/epoch - 5ms/step
# Epoch 52/120
# 7/7 - 0s - loss: 0.1194 - val_loss: 0.1318 - 38ms/epoch - 5ms/step
# Epoch 53/120
# 7/7 - 0s - loss: 0.1193 - val_loss: 0.1317 - 37ms/epoch - 5ms/step
# Epoch 54/120
# 7/7 - 0s - loss: 0.1193 - val_loss: 0.1318 - 41ms/epoch - 6ms/step
# Epoch 55/120
# 7/7 - 0s - loss: 0.1192 - val_loss: 0.1317 - 39ms/epoch - 6ms/step
# Epoch 56/120
# 7/7 - 0s - loss: 0.1192 - val_loss: 0.1317 - 41ms/epoch - 6ms/step
# Epoch 57/120
# 7/7 - 0s - loss: 0.1191 - val_loss: 0.1316 - 40ms/epoch - 6ms/step
# Epoch 58/120
# 7/7 - 0s - loss: 0.1191 - val_loss: 0.1317 - 41ms/epoch - 6ms/step
# Epoch 59/120
# 7/7 - 0s - loss: 0.1190 - val_loss: 0.1316 - 41ms/epoch - 6ms/step
# Epoch 60/120
# 7/7 - 0s - loss: 0.1189 - val_loss: 0.1316 - 40ms/epoch - 6ms/step
# Epoch 61/120
# 7/7 - 0s - loss: 0.1189 - val_loss: 0.1316 - 39ms/epoch - 6ms/step
# Epoch 62/120
# 7/7 - 0s - loss: 0.1189 - val_loss: 0.1315 - 41ms/epoch - 6ms/step
# Epoch 63/120
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1316 - 39ms/epoch - 6ms/step
# Epoch 64/120
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1315 - 41ms/epoch - 6ms/step
# Epoch 65/120
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1315 - 38ms/epoch - 5ms/step
# Epoch 66/120
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1314 - 42ms/epoch - 6ms/step
# Epoch 67/120
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1315 - 41ms/epoch - 6ms/step
# Epoch 68/120
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1314 - 40ms/epoch - 6ms/step
# Epoch 69/120
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1315 - 41ms/epoch - 6ms/step
# Epoch 70/120
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1314 - 40ms/epoch - 6ms/step
# Epoch 71/120
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1314 - 39ms/epoch - 6ms/step
# Epoch 72/120
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1314 - 39ms/epoch - 6ms/step
# Epoch 73/120
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1313 - 38ms/epoch - 5ms/step
# Epoch 74/120
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1313 - 37ms/epoch - 5ms/step
# Epoch 75/120
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1313 - 40ms/epoch - 6ms/step
# Epoch 76/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1313 - 38ms/epoch - 5ms/step
# Epoch 77/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1313 - 42ms/epoch - 6ms/step
# Epoch 78/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1313 - 41ms/epoch - 6ms/step
# Epoch 79/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1312 - 39ms/epoch - 6ms/step
# Epoch 80/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1313 - 40ms/epoch - 6ms/step
# Epoch 81/120
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1312 - 40ms/epoch - 6ms/step
# Epoch 82/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1313 - 42ms/epoch - 6ms/step
# Epoch 83/120
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1313 - 41ms/epoch - 6ms/step
# Epoch 84/120
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1313 - 40ms/epoch - 6ms/step
# Epoch 85/120
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1313 - 38ms/epoch - 5ms/step
# Epoch 86/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 38ms/epoch - 5ms/step
# Epoch 87/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 39ms/epoch - 6ms/step
# Epoch 88/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 39ms/epoch - 6ms/step
# Epoch 89/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 39ms/epoch - 6ms/step
# Epoch 90/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 39ms/epoch - 6ms/step
# Epoch 91/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 41ms/epoch - 6ms/step
# Epoch 92/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1312 - 41ms/epoch - 6ms/step
# Epoch 93/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1312 - 43ms/epoch - 6ms/step
# Epoch 94/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1312 - 40ms/epoch - 6ms/step
# Epoch 95/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 41ms/epoch - 6ms/step
# Epoch 96/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 97/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 98/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 38ms/epoch - 5ms/step
# Epoch 99/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 100/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 101/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 40ms/epoch - 6ms/step
# Epoch 102/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 49ms/epoch - 7ms/step
# Epoch 103/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 41ms/epoch - 6ms/step
# Epoch 104/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 43ms/epoch - 6ms/step
# Epoch 105/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 43ms/epoch - 6ms/step
# Epoch 106/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 107/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1312 - 40ms/epoch - 6ms/step
# Epoch 108/120
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1311 - 37ms/epoch - 5ms/step
# Epoch 109/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 110/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 38ms/epoch - 5ms/step
# Epoch 111/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 37ms/epoch - 5ms/step
# Epoch 112/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 41ms/epoch - 6ms/step
# Epoch 113/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 40ms/epoch - 6ms/step
# Epoch 114/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 115/120
# 7/7 - 0s - loss: 0.1179 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 116/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 117/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 40ms/epoch - 6ms/step
# Epoch 118/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 40ms/epoch - 6ms/step
# Epoch 119/120
# 7/7 - 0s - loss: 0.1180 - val_loss: 0.1310 - 44ms/epoch - 6ms/step
# Epoch 120/120
# 7/7 - 0s - loss: 0.1179 - val_loss: 0.1310 - 41ms/epoch - 6ms/step

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
final_predictions = model.predict(test_X)
print(final_predictions.shape)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# (97, 1)

# %%
train_predictions = model.predict(train_X)
print(train_predictions.shape)
# Out:
# 13/13 [==============================] - 0s 2ms/step
# (392, 1)

# %%
import pandas as pd

# %%
pd.DataFrame(train_y).to_csv('actualTrainLSTM .csv', index=False, header=False)
pd.DataFrame(train_predictions).to_csv('predictTrainLSTM .csv', index=False, header=False)
pd.DataFrame(test_y).to_csv('actualTestLSTM.csv', index=False, header=False)
pd.DataFrame(final_predictions).to_csv('predictTestLSTM.csv', index=False, header=False)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_evaluation_metrics(y_observed, y_predicted):
     # Convert to NumPy arrays if they are lists
    if isinstance(y_observed, list):
        y_observed = np.array(y_observed)
    if isinstance(y_predicted, list):
        y_predicted = np.array(y_predicted)
        
    metrics = {}

    # Calculate ME (Mean Error)
    metrics['ME'] = np.mean(y_observed - y_predicted)

    # Calculate MAE (Mean Absolute Error)
    metrics['MAE'] = mean_absolute_error(y_observed, y_predicted)

    # Calculate MSE (Mean Squared Error)
    metrics['MSE'] = mean_squared_error(y_observed, y_predicted)

    # Calculate RMSE (Root Mean Squared Error)
    metrics['RMSE'] = np.sqrt(metrics['MSE'])

    # Calculate NRMSE (Normalized Root Mean Squared Error)
    metrics['NRMSE'] = metrics['RMSE'] / (np.max(y_observed) - np.min(y_observed))

    # Calculate PBIAS (Percent Bias)
    metrics['PBIAS'] = np.mean(100 * (y_observed - y_predicted) / np.mean(y_observed))

    # Calculate RSR (Root Mean Square Ratio)
    metrics['RSR'] = metrics['RMSE'] / np.std(y_observed)

    # Calculate rSD (Ratio of the Standard Deviation)
    metrics['rSD'] = np.std(y_observed - y_predicted) / np.std(y_observed)

    # Calculate NSE (Nash-Sutcliffe Efficiency)
    metrics['NSE'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((y_observed - np.mean(y_observed)) ** 2))

    # Calculate mNSE (Modified Nash-Sutcliffe Efficiency)
    metrics['mNSE'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((y_observed - np.mean(y_observed)) ** 2))

    # Calculate rNSE (Relative Nash-Sutcliffe Efficiency)
    metrics['rNSE'] = metrics['NSE'] / np.var(y_observed)

    # Calculate d (Index of Agreement)
    metrics['d'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - np.mean(y_observed)) +
                                                                       np.abs(y_observed - np.mean(y_observed))) ** 2))

    # Calculate md (Modified d Index)
    metrics['md'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - np.mean(y_observed)) +
                                                                         np.abs(y_observed - np.mean(y_observed))) ** 2))

    # Calculate rd (Relative d Index)
    metrics['rd'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - np.mean(y_observed)) +
                                                                         np.abs(y_observed - np.mean(y_observed))) ** 2))

    # Calculate cp (Coefficient of Performance)
    metrics['cp'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - y_observed.mean()) +
                                                                         np.abs(y_observed - y_observed.mean())) ** 2))

    # Calculate r (Index of Agreement)
    metrics['r'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - y_observed.mean()) +
                                                                        np.abs(y_observed - y_observed.mean())) ** 2))

    # Calculate R2 (Coefficient of Determination)
    metrics['R2'] = r2_score(y_observed, y_predicted)

    return metrics

# %%
evaluation_metrics = calculate_evaluation_metrics(test_y, final_predictions)
print(evaluation_metrics)
# Out:
# {'ME': 0.0024716854, 'MAE': 0.13096906, 'MSE': 0.028510941, 'RMSE': 0.16885184, 'NRMSE': 0.17419526, 'PBIAS': 0.4943481, 'RSR': 0.5268034, 'rSD': 1.3472, 'NSE': -175.0557098388672, 'mNSE': -175.0557098388672, 'rNSE': -1703.9693163998957, 'd': 0.4474870562553406, 'md': 0.4474870562553406, 'rd': 0.4474870562553406, 'cp': 0.4474870562553406, 'r': 0.4474870562553406, 'R2': 0.7224782405354984}

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense

# Design network
model = Sequential()
model.add(GRU(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# Fit network
history = model.fit(train_X, train_y, epochs=200, batch_size=64, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/200
# 7/7 - 2s - loss: 0.4600 - val_loss: 0.3664 - 2s/epoch - 287ms/step
# Epoch 2/200
# 7/7 - 0s - loss: 0.3325 - val_loss: 0.2864 - 41ms/epoch - 6ms/step
# Epoch 3/200
# 7/7 - 0s - loss: 0.2491 - val_loss: 0.2513 - 40ms/epoch - 6ms/step
# Epoch 4/200
# 7/7 - 0s - loss: 0.2157 - val_loss: 0.2482 - 37ms/epoch - 5ms/step
# Epoch 5/200
# 7/7 - 0s - loss: 0.2116 - val_loss: 0.2461 - 38ms/epoch - 5ms/step
# Epoch 6/200
# 7/7 - 0s - loss: 0.2077 - val_loss: 0.2360 - 35ms/epoch - 5ms/step
# Epoch 7/200
# 7/7 - 0s - loss: 0.2007 - val_loss: 0.2267 - 39ms/epoch - 6ms/step
# Epoch 8/200
# 7/7 - 0s - loss: 0.1961 - val_loss: 0.2212 - 40ms/epoch - 6ms/step
# Epoch 9/200
# 7/7 - 0s - loss: 0.1913 - val_loss: 0.2151 - 40ms/epoch - 6ms/step
# Epoch 10/200
# 7/7 - 0s - loss: 0.1859 - val_loss: 0.2095 - 38ms/epoch - 5ms/step
# Epoch 11/200
# 7/7 - 0s - loss: 0.1807 - val_loss: 0.2037 - 38ms/epoch - 5ms/step
# Epoch 12/200
# 7/7 - 0s - loss: 0.1756 - val_loss: 0.1979 - 40ms/epoch - 6ms/step
# Epoch 13/200
# 7/7 - 0s - loss: 0.1706 - val_loss: 0.1921 - 39ms/epoch - 6ms/step
# Epoch 14/200
# 7/7 - 0s - loss: 0.1654 - val_loss: 0.1861 - 40ms/epoch - 6ms/step
# Epoch 15/200
# 7/7 - 0s - loss: 0.1602 - val_loss: 0.1797 - 40ms/epoch - 6ms/step
# Epoch 16/200
# 7/7 - 0s - loss: 0.1548 - val_loss: 0.1729 - 42ms/epoch - 6ms/step
# Epoch 17/200
# 7/7 - 0s - loss: 0.1494 - val_loss: 0.1661 - 40ms/epoch - 6ms/step
# Epoch 18/200
# 7/7 - 0s - loss: 0.1439 - val_loss: 0.1594 - 39ms/epoch - 6ms/step
# Epoch 19/200
# 7/7 - 0s - loss: 0.1392 - val_loss: 0.1532 - 40ms/epoch - 6ms/step
# Epoch 20/200
# 7/7 - 0s - loss: 0.1354 - val_loss: 0.1475 - 40ms/epoch - 6ms/step
# Epoch 21/200
# 7/7 - 0s - loss: 0.1319 - val_loss: 0.1425 - 40ms/epoch - 6ms/step
# Epoch 22/200
# 7/7 - 0s - loss: 0.1290 - val_loss: 0.1384 - 40ms/epoch - 6ms/step
# Epoch 23/200
# 7/7 - 0s - loss: 0.1267 - val_loss: 0.1352 - 38ms/epoch - 5ms/step
# Epoch 24/200
# 7/7 - 0s - loss: 0.1248 - val_loss: 0.1334 - 40ms/epoch - 6ms/step
# Epoch 25/200
# 7/7 - 0s - loss: 0.1238 - val_loss: 0.1330 - 37ms/epoch - 5ms/step
# Epoch 26/200
# 7/7 - 0s - loss: 0.1233 - val_loss: 0.1317 - 37ms/epoch - 5ms/step
# Epoch 27/200
# 7/7 - 0s - loss: 0.1227 - val_loss: 0.1319 - 44ms/epoch - 6ms/step
# Epoch 28/200
# 7/7 - 0s - loss: 0.1223 - val_loss: 0.1317 - 41ms/epoch - 6ms/step
# Epoch 29/200
# 7/7 - 0s - loss: 0.1219 - val_loss: 0.1314 - 42ms/epoch - 6ms/step
# Epoch 30/200
# 7/7 - 0s - loss: 0.1215 - val_loss: 0.1313 - 42ms/epoch - 6ms/step
# Epoch 31/200
# 7/7 - 0s - loss: 0.1211 - val_loss: 0.1316 - 42ms/epoch - 6ms/step
# Epoch 32/200
# 7/7 - 0s - loss: 0.1209 - val_loss: 0.1310 - 43ms/epoch - 6ms/step
# Epoch 33/200
# 7/7 - 0s - loss: 0.1205 - val_loss: 0.1310 - 40ms/epoch - 6ms/step
# Epoch 34/200
# 7/7 - 0s - loss: 0.1202 - val_loss: 0.1309 - 41ms/epoch - 6ms/step
# Epoch 35/200
# 7/7 - 0s - loss: 0.1199 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 36/200
# 7/7 - 0s - loss: 0.1197 - val_loss: 0.1306 - 40ms/epoch - 6ms/step
# Epoch 37/200
# 7/7 - 0s - loss: 0.1196 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 38/200
# 7/7 - 0s - loss: 0.1194 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 39/200
# 7/7 - 0s - loss: 0.1193 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 40/200
# 7/7 - 0s - loss: 0.1192 - val_loss: 0.1304 - 39ms/epoch - 6ms/step
# Epoch 41/200
# 7/7 - 0s - loss: 0.1191 - val_loss: 0.1305 - 38ms/epoch - 5ms/step
# Epoch 42/200
# 7/7 - 0s - loss: 0.1190 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 43/200
# 7/7 - 0s - loss: 0.1190 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 44/200
# 7/7 - 0s - loss: 0.1189 - val_loss: 0.1306 - 39ms/epoch - 6ms/step
# Epoch 45/200
# 7/7 - 0s - loss: 0.1189 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 46/200
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1306 - 43ms/epoch - 6ms/step
# Epoch 47/200
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 48/200
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1306 - 41ms/epoch - 6ms/step
# Epoch 49/200
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 50/200
# 7/7 - 0s - loss: 0.1188 - val_loss: 0.1305 - 40ms/epoch - 6ms/step
# Epoch 51/200
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1306 - 39ms/epoch - 6ms/step
# Epoch 52/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1306 - 39ms/epoch - 6ms/step
# Epoch 53/200
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1304 - 39ms/epoch - 6ms/step
# Epoch 54/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1307 - 36ms/epoch - 5ms/step
# Epoch 55/200
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1305 - 35ms/epoch - 5ms/step
# Epoch 56/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1307 - 36ms/epoch - 5ms/step
# Epoch 57/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1305 - 39ms/epoch - 6ms/step
# Epoch 58/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 38ms/epoch - 5ms/step
# Epoch 59/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1305 - 43ms/epoch - 6ms/step
# Epoch 60/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 61/200
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1305 - 38ms/epoch - 5ms/step
# Epoch 62/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 41ms/epoch - 6ms/step
# Epoch 63/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 41ms/epoch - 6ms/step
# Epoch 64/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 37ms/epoch - 5ms/step
# Epoch 65/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 40ms/epoch - 6ms/step
# Epoch 66/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 67/200
# 7/7 - 0s - loss: 0.1187 - val_loss: 0.1306 - 39ms/epoch - 6ms/step
# Epoch 68/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 40ms/epoch - 6ms/step
# Epoch 69/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 70/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 42ms/epoch - 6ms/step
# Epoch 71/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 40ms/epoch - 6ms/step
# Epoch 72/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 73/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1306 - 82ms/epoch - 12ms/step
# Epoch 74/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 54ms/epoch - 8ms/step
# Epoch 75/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 47ms/epoch - 7ms/step
# Epoch 76/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 46ms/epoch - 7ms/step
# Epoch 77/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 46ms/epoch - 7ms/step
# Epoch 78/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 43ms/epoch - 6ms/step
# Epoch 79/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 43ms/epoch - 6ms/step
# Epoch 80/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 42ms/epoch - 6ms/step
# Epoch 81/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1310 - 41ms/epoch - 6ms/step
# Epoch 82/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1307 - 40ms/epoch - 6ms/step
# Epoch 83/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 38ms/epoch - 5ms/step
# Epoch 84/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 85/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 41ms/epoch - 6ms/step
# Epoch 86/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 87/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 40ms/epoch - 6ms/step
# Epoch 88/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 49ms/epoch - 7ms/step
# Epoch 89/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 42ms/epoch - 6ms/step
# Epoch 90/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1308 - 42ms/epoch - 6ms/step
# Epoch 91/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 42ms/epoch - 6ms/step
# Epoch 92/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 42ms/epoch - 6ms/step
# Epoch 93/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 39ms/epoch - 6ms/step
# Epoch 94/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 40ms/epoch - 6ms/step
# Epoch 95/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1308 - 37ms/epoch - 5ms/step
# Epoch 96/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 42ms/epoch - 6ms/step
# Epoch 97/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 40ms/epoch - 6ms/step
# Epoch 98/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 99/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 40ms/epoch - 6ms/step
# Epoch 100/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 37ms/epoch - 5ms/step
# Epoch 101/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 37ms/epoch - 5ms/step
# Epoch 102/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 38ms/epoch - 5ms/step
# Epoch 103/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 40ms/epoch - 6ms/step
# Epoch 104/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1308 - 39ms/epoch - 6ms/step
# Epoch 105/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 106/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 37ms/epoch - 5ms/step
# Epoch 107/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1310 - 37ms/epoch - 5ms/step
# Epoch 108/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 36ms/epoch - 5ms/step
# Epoch 109/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 110/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 38ms/epoch - 5ms/step
# Epoch 111/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 112/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 113/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1308 - 38ms/epoch - 5ms/step
# Epoch 114/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 37ms/epoch - 5ms/step
# Epoch 115/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 38ms/epoch - 5ms/step
# Epoch 116/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 117/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 118/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 37ms/epoch - 5ms/step
# Epoch 119/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 120/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 37ms/epoch - 5ms/step
# Epoch 121/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 38ms/epoch - 5ms/step
# Epoch 122/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 123/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1308 - 35ms/epoch - 5ms/step
# Epoch 124/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 37ms/epoch - 5ms/step
# Epoch 125/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 39ms/epoch - 6ms/step
# Epoch 126/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 37ms/epoch - 5ms/step
# Epoch 127/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 39ms/epoch - 6ms/step
# Epoch 128/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 129/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 130/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 36ms/epoch - 5ms/step
# Epoch 131/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 66ms/epoch - 9ms/step
# Epoch 132/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 37ms/epoch - 5ms/step
# Epoch 133/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 134/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1310 - 35ms/epoch - 5ms/step
# Epoch 135/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 36ms/epoch - 5ms/step
# Epoch 136/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 137/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 37ms/epoch - 5ms/step
# Epoch 138/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 139/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 37ms/epoch - 5ms/step
# Epoch 140/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 38ms/epoch - 5ms/step
# Epoch 141/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 142/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 40ms/epoch - 6ms/step
# Epoch 143/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1311 - 43ms/epoch - 6ms/step
# Epoch 144/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1308 - 42ms/epoch - 6ms/step
# Epoch 145/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 40ms/epoch - 6ms/step
# Epoch 146/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1312 - 41ms/epoch - 6ms/step
# Epoch 147/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1306 - 42ms/epoch - 6ms/step
# Epoch 148/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 149/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 40ms/epoch - 6ms/step
# Epoch 150/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1311 - 42ms/epoch - 6ms/step
# Epoch 151/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 36ms/epoch - 5ms/step
# Epoch 152/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1309 - 37ms/epoch - 5ms/step
# Epoch 153/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1308 - 38ms/epoch - 5ms/step
# Epoch 154/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1307 - 41ms/epoch - 6ms/step
# Epoch 155/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1310 - 41ms/epoch - 6ms/step
# Epoch 156/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 39ms/epoch - 6ms/step
# Epoch 157/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1309 - 41ms/epoch - 6ms/step
# Epoch 158/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 38ms/epoch - 5ms/step
# Epoch 159/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1309 - 38ms/epoch - 5ms/step
# Epoch 160/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 161/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1309 - 39ms/epoch - 6ms/step
# Epoch 162/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 163/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 36ms/epoch - 5ms/step
# Epoch 164/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1308 - 39ms/epoch - 6ms/step
# Epoch 165/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1311 - 38ms/epoch - 5ms/step
# Epoch 166/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1307 - 36ms/epoch - 5ms/step
# Epoch 167/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1308 - 40ms/epoch - 6ms/step
# Epoch 168/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 169/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1306 - 39ms/epoch - 6ms/step
# Epoch 170/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1307 - 41ms/epoch - 6ms/step
# Epoch 171/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 41ms/epoch - 6ms/step
# Epoch 172/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1307 - 40ms/epoch - 6ms/step
# Epoch 173/200
# 7/7 - 0s - loss: 0.1181 - val_loss: 0.1308 - 38ms/epoch - 5ms/step
# Epoch 174/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1312 - 39ms/epoch - 6ms/step
# Epoch 175/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1308 - 39ms/epoch - 6ms/step
# Epoch 176/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 177/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 40ms/epoch - 6ms/step
# Epoch 178/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1308 - 42ms/epoch - 6ms/step
# Epoch 179/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 42ms/epoch - 6ms/step
# Epoch 180/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1314 - 42ms/epoch - 6ms/step
# Epoch 181/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1309 - 60ms/epoch - 9ms/step
# Epoch 182/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 183/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1310 - 37ms/epoch - 5ms/step
# Epoch 184/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 37ms/epoch - 5ms/step
# Epoch 185/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 186/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 187/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1308 - 41ms/epoch - 6ms/step
# Epoch 188/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1312 - 40ms/epoch - 6ms/step
# Epoch 189/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1309 - 41ms/epoch - 6ms/step
# Epoch 190/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1309 - 40ms/epoch - 6ms/step
# Epoch 191/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1314 - 39ms/epoch - 6ms/step
# Epoch 192/200
# 7/7 - 0s - loss: 0.1186 - val_loss: 0.1308 - 38ms/epoch - 5ms/step
# Epoch 193/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1312 - 37ms/epoch - 5ms/step
# Epoch 194/200
# 7/7 - 0s - loss: 0.1185 - val_loss: 0.1308 - 40ms/epoch - 6ms/step
# Epoch 195/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1311 - 37ms/epoch - 5ms/step
# Epoch 196/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1311 - 39ms/epoch - 6ms/step
# Epoch 197/200
# 7/7 - 0s - loss: 0.1183 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 198/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 199/200
# 7/7 - 0s - loss: 0.1182 - val_loss: 0.1310 - 39ms/epoch - 6ms/step
# Epoch 200/200
# 7/7 - 0s - loss: 0.1184 - val_loss: 0.1308 - 39ms/epoch - 6ms/step

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
final_predictions = model.predict(test_X)
print(final_predictions.shape)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# (97, 1)

# %%
train_predictions = model.predict(train_X)
print(train_predictions.shape)
# Out:
# 13/13 [==============================] - 0s 1ms/step
# (392, 1)

# %%
evaluation_metrics = calculate_evaluation_metrics(test_y, final_predictions)
print(evaluation_metrics)
# Out:
# {'ME': 0.005322414, 'MAE': 0.13081482, 'MSE': 0.028374223, 'RMSE': 0.1684465, 'NRMSE': 0.17377709, 'PBIAS': 1.0645053, 'RSR': 0.52553874, 'rSD': 1.3431498, 'NSE': -174.0196990966797, 'mNSE': -174.0196990966797, 'rNSE': -1693.8849237355655, 'd': 0.44720184803009033, 'md': 0.44720184803009033, 'rd': 0.44720184803009033, 'cp': 0.44720184803009033, 'r': 0.44720184803009033, 'R2': 0.7238091016706445}

# %%
pd.DataFrame(train_y).to_csv('actualTrainGRU .csv', index=False, header=False)
pd.DataFrame(train_predictions).to_csv('predictTrainGRU.csv', index=False, header=False)
pd.DataFrame(test_y).to_csv('actualTestGRU.csv', index=False, header=False)
pd.DataFrame(final_predictions).to_csv('predictTestGRU.csv', index=False, header=False)
