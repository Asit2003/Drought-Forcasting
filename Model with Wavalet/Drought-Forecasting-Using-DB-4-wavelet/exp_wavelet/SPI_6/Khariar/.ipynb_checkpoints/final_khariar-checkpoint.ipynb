# %%
import pandas as pd

# %%
import numpy as np
import pdb
import pywt
from scipy.ndimage import convolve1d

# %%
def upArrow_op(li, j):
    if j == 0:
        return [1]
    N = len(li)
    li_n = np.zeros(2**(j - 1) * (N - 1) + 1)
    for i in range(N):
        li_n[2**(j - 1) * i] = li[i]
    return li_n


def period_list(li, N):
    n = len(li)
    # append [0 0 ...]
    n_app = N - np.mod(n, N)
    li = list(li)
    li = li + [0] * n_app
    if len(li) < 2 * N:
        return np.array(li)
    else:
        li = np.array(li)
        li = np.reshape(li, [-1, N])
        li = np.sum(li, axis=0)
        return li


def circular_convolve_mra(h_j_o, w_j):
    ''' calculate the mra D_j'''
    return convolve1d(w_j,
                      np.flip(h_j_o),
                      mode="wrap",
                      origin=(len(h_j_o) - 1) // 2)


def circular_convolve_d(h_t, v_j_1, j):
    '''
    jth level decomposition
    h_t: \tilde{h} = h / sqrt(2)
    v_j_1: v_{j-1}, the (j-1)th scale coefficients
    return: w_j (or v_j)
    '''
    N = len(v_j_1)
    w_j = np.zeros(N)
    ker = np.zeros(len(h_t) * 2**(j - 1))

    # make kernel
    for i, h in enumerate(h_t):
        ker[i * 2**(j - 1)] = h

    w_j = convolve1d(v_j_1, ker, mode="wrap", origin=-len(ker) // 2)
    return w_j


def circular_convolve_s(h_t, g_t, w_j, v_j, j):
    '''
    (j-1)th level synthesis from w_j, w_j
    see function circular_convolve_d
    '''
    N = len(v_j)

    h_ker = np.zeros(len(h_t) * 2**(j - 1))
    g_ker = np.zeros(len(g_t) * 2**(j - 1))

    for i, (h, g) in enumerate(zip(h_t, g_t)):
        h_ker[i * 2**(j - 1)] = h
        g_ker[i * 2**(j - 1)] = g

    v_j_1 = np.zeros(N)

    v_j_1 = convolve1d(w_j,
                       np.flip(h_ker),
                       mode="wrap",
                       origin=(len(h_ker) - 1) // 2)
    v_j_1 += convolve1d(v_j,
                        np.flip(g_ker),
                        mode="wrap",
                        origin=(len(g_ker) - 1) // 2)
    return v_j_1


def modwt(x, filters, level):
    '''
    filters: 'db1', 'db2', 'haar', ...
    return: see matlab
    '''
    # filter
    wavelet = pywt.Wavelet(filters)
    h = wavelet.dec_hi
    g = wavelet.dec_lo
    h_t = np.array(h) / np.sqrt(2)
    g_t = np.array(g) / np.sqrt(2)
    wavecoeff = []
    v_j_1 = x
    for j in range(level):
        w = circular_convolve_d(h_t, v_j_1, j + 1)
        v_j_1 = circular_convolve_d(g_t, v_j_1, j + 1)
        wavecoeff.append(w)
    wavecoeff.append(v_j_1)
    return np.vstack(wavecoeff)


def imodwt(w, filters):
    ''' inverse modwt '''
    # filter
    wavelet = pywt.Wavelet(filters)
    h = wavelet.dec_hi
    g = wavelet.dec_lo
    h_t = np.array(h) / np.sqrt(2)
    g_t = np.array(g) / np.sqrt(2)
    level = len(w) - 1
    v_j = w[-1]
    for jp in range(level):
        j = level - jp - 1
        v_j = circular_convolve_s(h_t, g_t, w[j], v_j, j + 1)
    return v_j


def modwtmra(w, filters):
    ''' Multiresolution analysis based on MODWT'''
    # filter
    wavelet = pywt.Wavelet(filters)
    h = wavelet.dec_hi
    g = wavelet.dec_lo
    # D
    level, N = w.shape
    level = level - 1
    D = []
    g_j_part = [1]
    for j in range(level):
        # g_j_part
        g_j_up = upArrow_op(g, j)
        g_j_part = np.convolve(g_j_part, g_j_up)
        # h_j_o
        h_j_up = upArrow_op(h, j + 1)
        h_j = np.convolve(g_j_part, h_j_up)
        h_j_t = h_j / (2**((j + 1) / 2.))
        if j == 0: h_j_t = h / np.sqrt(2)
        h_j_t_o = period_list(h_j_t, N)
        D.append(circular_convolve_mra(h_j_t_o, w[j]))
    # S
    j = level - 1
    g_j_up = upArrow_op(g, j + 1)
    g_j = np.convolve(g_j_part, g_j_up)
    g_j_t = g_j / (2**((j + 1) / 2.))
    g_j_t_o = period_list(g_j_t, N)
    S = circular_convolve_mra(g_j_t_o, w[-1])
    D.append(S)
    return np.vstack(D)

# %%
x = pd.read_csv(r"spi_6.csv")

# %%
x.isnull().sum()
# Out:
# sl.no.      0
# rainfall    0
# spi_6       0
# dtype: int64

# %%
x = x["spi_6"].values

# %%
print(x)
# Out:
# [ 0.14  0.55  1.02  1.31  1.31  1.2   0.79  0.44 -0.08 -0.86 -0.76 -0.38
#   0.09  0.7   1.23  1.31  1.32  1.21  0.97  0.41 -0.82 -1.35 -1.95 -1.62
#  -0.55 -0.02  0.51  0.78  0.89  0.84  0.57  0.27 -0.37 -1.06 -1.62 -1.35
#  -0.49  0.39  0.78  0.89  0.88  0.84  0.56 -0.12 -0.98 -1.51 -1.62 -1.56
#  -0.96 -0.11  0.45  0.81  0.93  0.93  0.81  0.38 -0.17 -0.93 -1.39 -1.24
#   0.01  0.45  0.95  1.12  1.12  1.16  0.7   0.29 -0.6  -1.24 -1.39 -1.67
#  -1.03 -0.13  0.25  0.42  0.55  0.56  0.43 -0.11 -0.55 -0.96 -1.47 -1.56
#  -0.7  -0.23  0.2   0.41  0.41  0.38  0.07 -0.28 -1.09 -2.05 -2.16 -1.95
#  -0.3   0.29  0.84  1.07  1.07  1.06  0.66  0.21 -0.6  -1.56 -1.43 -0.59
#   0.07  0.53  0.98  1.26  1.45  1.29  0.99  0.65  0.02 -0.68 -2.3  -2.78
#  -0.84  0.02  0.62  0.79  0.83  0.86  0.63  0.12 -0.82 -1.56 -1.67 -1.47
#  -0.84  0.    0.67  0.88  0.86  0.82  0.67  0.19 -0.8  -1.73 -1.56 -1.43
#  -0.52  0.4   0.88  1.11  1.15  1.11  0.88  0.25 -0.52 -1.51 -2.3  -1.39
#  -0.3   0.71  1.11  1.37  1.41  1.35  1.06  0.39 -0.28 -1.01 -1.27 -0.98
#  -0.52  0.35  0.75  0.97  1.04  0.99  0.83  0.13 -0.5  -1.27 -1.67 -1.73
#  -1.03 -0.06  0.45  0.59  0.61  0.61  0.47 -0.07 -0.93 -1.39 -1.14 -1.12
#  -0.68  0.17  0.73  0.79  0.7   0.72  0.64  0.05 -0.91 -1.18 -1.14 -1.12
#  -0.72 -0.14  0.27  0.48  0.65  0.7   0.51  0.15 -0.32 -0.78 -1.47 -1.73
#  -0.76 -0.24  0.66  0.93  0.97  0.92  0.72  0.47 -0.52 -1.51 -1.87 -1.51
#  -0.23  0.33  0.58  0.7   0.7   0.66  0.15 -0.49 -1.31 -2.05 -1.73 -1.31
#  -0.15  0.45  0.9   1.02  1.07  1.03  0.63  0.14 -0.68 -1.12 -1.56 -1.47
#  -0.54 -0.23  0.35  0.45  0.49  0.45  0.1  -0.19 -1.12 -1.43 -1.62 -1.62
#  -1.09  0.09  0.78  1.1   1.27  1.27  1.24  0.84  0.14 -0.5  -1.12 -1.01
#  -0.28  0.26  0.61  0.88  0.91  0.88  0.54  0.11 -0.4  -1.27 -1.51 -1.24
#  -0.62  0.32  0.78  1.14  1.3   1.26  1.11  0.5  -0.06 -0.82 -1.35 -0.96
#  -0.64  0.26  0.75  1.04  0.98  0.93  0.82  0.25 -0.41 -1.73 -1.73 -1.8
#   0.19  0.64  1.    1.21  1.23  1.22  0.55  0.1  -0.6  -1.24 -1.35 -1.39
#  -0.43  0.09  0.51  0.91  0.91  0.9   0.61  0.23 -0.32 -2.3  -2.3  -1.8
#  -1.18  0.35  0.77  0.86  0.91  0.92  0.84 -0.02 -0.82 -1.21 -1.35 -1.43
#  -0.6   0.37  0.77  1.11  1.16  1.17  1.02  0.41 -0.07 -0.93 -0.82 -0.78
#  -0.43  0.32  0.89  1.27  1.18  1.13  0.97  0.54 -0.2  -1.67 -1.39 -1.27
#  -0.4   0.64  1.25  1.5   1.49  1.5   1.26  0.57 -0.41 -1.67 -1.43 -1.67
#  -0.15  0.68  1.09  1.27  1.39  1.72  1.75  1.3   0.96  0.76  0.59  0.
#  -0.78  0.39  0.72  1.09  1.13  1.11  0.99  0.3  -0.23 -1.27 -1.56 -1.39
#  -0.13  0.28  0.75  1.07  1.03  1.01  0.58  0.24 -0.46 -2.05 -1.95 -1.73
#  -0.68  0.24  0.67  1.08  1.18  1.16  0.94  0.41 -0.09 -1.18 -2.16 -2.05
#  -0.72  0.32  0.75  0.99  1.09  1.08  0.86  0.19 -0.43 -1.27 -1.67 -1.47
#  -0.84  0.07  0.79  0.93  0.91  0.88  0.81  0.34 -0.72 -1.24 -1.27 -1.14
#  -0.88  0.23  0.93  1.39  1.46  1.44  1.33  0.85  0.22 -0.74 -1.01 -0.66
#   0.14  0.57  1.06  1.21  1.25  1.16  0.77  0.39 -0.6  -1.47 -2.16 -1.13
#  -0.32  0.5   0.78  1.18  1.19  1.11  0.93]

# %%
# Step 1: Choose a wavelet
wavelet = 'db4'  # Example: Dmey wavelet, you can change it to any other wavelet

# Step 2: Determine the maximum decomposition level
def get_max_level(data_length):
    return pywt.dwt_max_level(data_length, wavelet)

# %%
data = pd.read_csv(r"spi_6.csv")     # Replace with your non-stationary time series

max_level = get_max_level(len(data))
max_level
# Out:
# 6

# %%
x.dtype
# Out:
# dtype('float64')

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the wavelet filters
wavelet_filters = 'db2'  # Replace with the desired wavelet filters

# Define the decomposition level
decomposition_level = 7  # Replace with the desired level

# Perform MODWT
wavelet_coefficients = modwt(x, wavelet_filters, decomposition_level)

# Plot the wavelet coefficients
fig, ax = plt.subplots(decomposition_level + 1, 1, figsize=(15, 15))

# Plot the original signal
ax[0].plot(x, color='blue')
ax[0].set_ylabel('Original Signal')

# Plot the wavelet coefficients at each level
for i in range(decomposition_level):
    ax[i + 1].plot(wavelet_coefficients[i], color='red')
    ax[i + 1].set_ylabel(f'Level {i + 1} Coefficients')

plt.xlabel('Time')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the wavelet filters
wavelet_filters = 'db2'  # Replace with the desired wavelet filters

# Define the decomposition level
decomposition_level = 7  # Replace with the desired level

# Perform MODWT
wavelet_coefficients = modwt(x, wavelet_filters, decomposition_level)

# Plot the wavelet coefficients
fig, ax = plt.subplots(decomposition_level + 1, 1, figsize=(10, 10))

# Plot the original signal
ax[0].plot(x, color='blue')
ax[0].set_ylabel('Original Signal')

# Plot the wavelet coefficients at each level
for i in range(decomposition_level):
    ax[i + 1].plot(wavelet_coefficients[i], color='red')
    ax[i + 1].set_ylabel(f'Level {i + 1}')

    # Plot the zero line for clarity
    ax[i + 1].axhline(0, color='black', linestyle='--')

plt.xlabel('Time')
plt.tight_layout()
plt.show()

# %%
lev = 6
w = modwt(x, 'sym4', lev)
fig, ax = plt.subplots(lev + 1, 1, sharex=True)
for k in range(lev + 1):
    ax[k].plot(w[k])

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the wavelet filters
wavelet_filters = 'db2'  # Replace with the desired wavelet filters

# Define the decomposition level
decomposition_level = 7  # Replace with the desired level

# Perform MODWT
wavelet_coefficients = modwt(x, wavelet_filters, decomposition_level)

# Plot the wavelet coefficients and approximation
fig, ax = plt.subplots(decomposition_level + 2, 1, figsize=(10, 10))

# Plot the original signal
ax[0].plot(x, color='blue')
ax[0].set_ylabel('Original Signal')

# Plot the approximation coefficients
ax[1].plot(wavelet_coefficients[-1], color='green')
ax[1].set_ylabel('Approximation Coefficients')

# Plot the wavelet coefficients at each level
for i in range(decomposition_level):
    ax[i + 2].plot(wavelet_coefficients[i], color='red')
    ax[i + 2].set_ylabel(f'Level {i + 1} Coefficients')

#     # Plot the zero line for clarity
#     ax[i + 2].axhline(0, color='black', linestyle='--')

plt.xlabel('Time')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



# Define the wavelet filters
wavelet_filters = 'db2'  # Replace with the desired wavelet filters

# Define the decomposition level
decomposition_level = 7  # Replace with the desired level

# Perform MODWT
wavelet_coefficients = modwt(x, wavelet_filters, decomposition_level)

# Export the original signal to CSV
np.savetxt('original_signal.csv', x, delimiter=',')

# Combine the detail coefficients to reconstruct the original signal
reconstructed_signal = imodwt(wavelet_coefficients, wavelet_filters)

# Plot the original signal and the reconstructed signal
plt.figure(figsize=(8, 6))
plt.plot(x, color='blue', label='Original Signal')
plt.plot(reconstructed_signal, color='red', linestyle='--', label='Reconstructed Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the wavelet filters
wavelet_filters = 'db2'  # Replace with the desired wavelet filters

# Define the decomposition level
decomposition_level = 7 # Replace with the desired level

# Perform MODWT
wavelet_coefficients = modwt(x, wavelet_filters, decomposition_level)

# Plot the wavelet coefficients and approximation
fig, ax = plt.subplots(decomposition_level + 2, 1, figsize=(10, 10))

# Plot the original signal
ax[0].plot(x, color='blue')
ax[0].set_ylabel('Original Signal')

# Plot the approximation coefficients
ax[1].plot(wavelet_coefficients[-1], color='green')
ax[1].set_ylabel('Approximation')

# Plot the wavelet coefficients at each level
for i in range(decomposition_level):
    ax[i + 2].plot(wavelet_coefficients[i], color='red')
    ax[i + 2].set_ylabel(f'D {i + 1} ')

    # Plot the zero line for clarity
    ax[i + 2].axhline(0, color='black', linestyle='--')

plt.xlabel('Time')
plt.tight_layout()
plt.show()

# Prepare data for export
data_export = np.vstack((x, wavelet_coefficients[-1], *wavelet_coefficients[:-1]))

# Define column names
column_names = ['Original Signal', 'Approximation']
column_names += [f'D {i+1}' for i in range(decomposition_level)]

# Export data to CSV
np.savetxt('wavelet_coefficients.csv', data_export.T, delimiter=',', header=','.join(column_names), comments='')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\asitg\\Desktop\\intern pkd\\exp_wavelet\\Khariar'

# %%
import numpy as np
import matplotlib.pyplot as plt


# Define the wavelet filters
wavelet_filters = 'db4'  # Replace with the desired wavelet filters

# Define the decomposition level
decomposition_level = 6 # Replace with the desired level

# Perform MODWT
wavelet_coefficients = modwt(x, wavelet_filters, decomposition_level)

# Plot the wavelet coefficients and approximation
fig, ax = plt.subplots(decomposition_level + 2, 1, figsize=(8, 10))

# Plot the original signal
ax[0].plot(x, color='blue')
ax[0].set_ylabel('Original Signal')

# Plot the approximation coefficients
ax[1].plot(wavelet_coefficients[-1], color='green')
ax[1].set_ylabel('Approximation')

# Plot the wavelet coefficients at each level
for i in range(decomposition_level):
    ax[i + 2].plot(wavelet_coefficients[i], color='red')
    ax[i + 2].set_ylabel(f'D {i + 1} ')

    # Plot the zero line for clarity
    ax[i + 2].axhline(0, color='black', linestyle='--')

plt.xlabel('Time')
plt.tight_layout()
plt.savefig('spi_6_khariar_wavelet_all.png', dpi=1200, bbox_inches='tight')
plt.show()

# Prepare data for export
data_export = np.vstack((x, wavelet_coefficients[-1], *wavelet_coefficients[:-1]))

# Define column names
column_names = ['Original Signal', 'Approximation']
column_names += [f'D {i+1}' for i in range(decomposition_level)]

# Export data to CSV
np.savetxt('wavelet_coefficients_db4.csv', data_export.T, delimiter=',', header=','.join(column_names), comments='')
