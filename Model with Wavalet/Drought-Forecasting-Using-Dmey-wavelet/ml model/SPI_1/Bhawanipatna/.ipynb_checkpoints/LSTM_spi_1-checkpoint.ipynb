# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = read_csv('wavelet_coefficients_dmey.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0,1,3]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
plt.savefig('spi_1_bhawanipatna_wavelet_GA.png', dpi=1200, bbox_inches='tight')
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot as plt

# load dataset
dataset = read_csv('wavelet_coefficients_dmey.csv', header=0, index_col=0)
values = dataset.values

# specify columns to plot
groups = [0, 1, 3]
num_groups = len(groups)

# define figure size
fig_width = 8
fig_height = 2 * num_groups  # Adjust the height as per your preference
fig_size = (fig_width, fig_height)

# create the figure with specified size
plt.figure(figsize=fig_size)

# plot each column
for i, group in enumerate(groups, 1):
    plt.subplot(num_groups, 1, i)
    plt.plot(values[:, group])
    plt.title(dataset.columns[group], y=0.5, loc='right')

plt.savefig('spi_1_bhawanipatna_wavelet_GA.png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# load dataset
dataset = read_csv('wavelet_coefficients_dmey.csv')
dataset=dataset.drop(['Approximation','D 2'], axis=1)

# %%
dataset
# Out:
#      Original Signal       D 1       D 3
# 0              -0.29 -0.260332  0.604530
# 1              -0.44 -0.077935  0.152219
# 2              -0.06  0.029108 -0.338192
# 3               0.12  0.313468 -0.727674
# 4               0.56 -0.207662 -0.909092
# ..               ...       ...       ...
# 487             0.91 -0.162937 -0.314281
# 488             1.28 -0.043071  0.200575
# 489            -0.35 -0.062554  0.653961
# 490            -0.07 -0.043076  0.906529
# 491            -0.31  0.337955  0.885759
#
# [492 rows x 3 columns]

# %%
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,2] = encoder.fit_transform(values[:,2])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed)
# drop columns we don't want to predict
# reframed.drop(reframed.columns[[2,3,6]], axis=1, inplace=True)
# print(reframed.head())
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)
# 1     0.343931   0.345978   0.792261  0.300578  0.448416  0.572301
# 2     0.300578   0.448416   0.572301  0.410405  0.508534  0.346232
# 3     0.410405   0.508534   0.346232  0.462428  0.668236  0.128310
# 4     0.462428   0.668236   0.128310  0.589595  0.375559  0.028513
# 5     0.589595   0.375559   0.028513  0.748555  0.277386  0.059063
# ..         ...        ...        ...       ...       ...       ...
# 487   0.806358   0.779677   0.126273  0.690751  0.400677  0.356416
# 488   0.690751   0.400677   0.356416  0.797688  0.467996  0.584521
# 489   0.797688   0.467996   0.584521  0.326590  0.457055  0.822811
# 490   0.326590   0.457055   0.822811  0.407514  0.467994  0.961304
# 491   0.407514   0.467994   0.961304  0.338150  0.681988  0.953157
#
# [491 rows x 6 columns]

# %%
reframed
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)
# 1     0.343931   0.345978   0.792261  0.300578  0.448416  0.572301
# 2     0.300578   0.448416   0.572301  0.410405  0.508534  0.346232
# 3     0.410405   0.508534   0.346232  0.462428  0.668236  0.128310
# 4     0.462428   0.668236   0.128310  0.589595  0.375559  0.028513
# 5     0.589595   0.375559   0.028513  0.748555  0.277386  0.059063
# ..         ...        ...        ...       ...       ...       ...
# 487   0.806358   0.779677   0.126273  0.690751  0.400677  0.356416
# 488   0.690751   0.400677   0.356416  0.797688  0.467996  0.584521
# 489   0.797688   0.467996   0.584521  0.326590  0.457055  0.822811
# 490   0.326590   0.457055   0.822811  0.407514  0.467994  0.961304
# 491   0.407514   0.467994   0.961304  0.338150  0.681988  0.953157
#
# [491 rows x 6 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 392
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (392, 1, 5) (392,) (99, 1, 5) (99,)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def calculate_evaluation_metrics(y_observed, y_predicted):
     # Convert to NumPy arrays if they are lists
    if isinstance(y_observed, list):
        y_observed = np.array(y_observed)
    if isinstance(y_predicted, list):
        y_predicted = np.array(y_predicted)
        
    metrics = {}

    # Calculate ME (Mean Error)
    metrics['ME'] = np.mean(y_observed - y_predicted)

    # Calculate MAE (Mean Absolute Error)
    metrics['MAE'] = mean_absolute_error(y_observed, y_predicted)

    # Calculate MSE (Mean Squared Error)
    metrics['MSE'] = mean_squared_error(y_observed, y_predicted)

    # Calculate RMSE (Root Mean Squared Error)
    metrics['RMSE'] = np.sqrt(metrics['MSE'])

    # Calculate NRMSE (Normalized Root Mean Squared Error)
    metrics['NRMSE'] = metrics['RMSE'] / (np.max(y_observed) - np.min(y_observed))

    # Calculate PBIAS (Percent Bias)
    metrics['PBIAS'] = np.mean(100 * (y_observed - y_predicted) / np.mean(y_observed))

    # Calculate RSR (Root Mean Square Ratio)
    metrics['RSR'] = metrics['RMSE'] / np.std(y_observed)

    # Calculate rSD (Ratio of the Standard Deviation)
    metrics['rSD'] = np.std(y_observed - y_predicted) / np.std(y_observed)

    # Calculate NSE (Nash-Sutcliffe Efficiency)
    metrics['NSE'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((y_observed - np.mean(y_observed)) ** 2))

    # Calculate mNSE (Modified Nash-Sutcliffe Efficiency)
    metrics['mNSE'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((y_observed - np.mean(y_observed)) ** 2))

    # Calculate rNSE (Relative Nash-Sutcliffe Efficiency)
    metrics['rNSE'] = metrics['NSE'] / np.var(y_observed)

    # Calculate d (Index of Agreement)
    metrics['d'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - np.mean(y_observed)) +
                                                                       np.abs(y_observed - np.mean(y_observed))) ** 2))

    # Calculate md (Modified d Index)
    metrics['md'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - np.mean(y_observed)) +
                                                                         np.abs(y_observed - np.mean(y_observed))) ** 2))

    # Calculate rd (Relative d Index)
    metrics['rd'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - np.mean(y_observed)) +
                                                                         np.abs(y_observed - np.mean(y_observed))) ** 2))

    # Calculate cp (Coefficient of Performance)
    metrics['cp'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - y_observed.mean()) +
                                                                         np.abs(y_observed - y_observed.mean())) ** 2))

    # Calculate r (Index of Agreement)
    metrics['r'] = 1 - (np.sum((y_observed - y_predicted) ** 2) / np.sum((np.abs(y_predicted - y_observed.mean()) +
                                                                        np.abs(y_observed - y_observed.mean())) ** 2))

    # Calculate R2 (Coefficient of Determination)
    metrics['R2'] = r2_score(y_observed, y_predicted)

    return metrics

# %% [markdown]
# # RNN

# %%
from keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Design network
model = Sequential()
model.add(SimpleRNN(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# Fit network
history = model.fit(train_X, train_y, epochs=70, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/70
# 6/6 - 1s - loss: 0.1997 - val_loss: 0.1394 - 1s/epoch - 209ms/step
# Epoch 2/70
# 6/6 - 0s - loss: 0.1758 - val_loss: 0.1209 - 38ms/epoch - 6ms/step
# Epoch 3/70
# 6/6 - 0s - loss: 0.1535 - val_loss: 0.1036 - 33ms/epoch - 5ms/step
# Epoch 4/70
# 6/6 - 0s - loss: 0.1334 - val_loss: 0.0898 - 35ms/epoch - 6ms/step
# Epoch 5/70
# 6/6 - 0s - loss: 0.1166 - val_loss: 0.0804 - 34ms/epoch - 6ms/step
# Epoch 6/70
# 6/6 - 0s - loss: 0.1040 - val_loss: 0.0760 - 35ms/epoch - 6ms/step
# Epoch 7/70
# 6/6 - 0s - loss: 0.0958 - val_loss: 0.0758 - 21ms/epoch - 4ms/step
# Epoch 8/70
# 6/6 - 0s - loss: 0.0915 - val_loss: 0.0753 - 29ms/epoch - 5ms/step
# Epoch 9/70
# 6/6 - 0s - loss: 0.0895 - val_loss: 0.0768 - 22ms/epoch - 4ms/step
# Epoch 10/70
# 6/6 - 0s - loss: 0.0891 - val_loss: 0.0777 - 44ms/epoch - 7ms/step
# Epoch 11/70
# 6/6 - 0s - loss: 0.0883 - val_loss: 0.0782 - 33ms/epoch - 6ms/step
# Epoch 12/70
# 6/6 - 0s - loss: 0.0884 - val_loss: 0.0783 - 34ms/epoch - 6ms/step
# Epoch 13/70
# 6/6 - 0s - loss: 0.0880 - val_loss: 0.0780 - 34ms/epoch - 6ms/step
# Epoch 14/70
# 6/6 - 0s - loss: 0.0880 - val_loss: 0.0779 - 22ms/epoch - 4ms/step
# Epoch 15/70
# 6/6 - 0s - loss: 0.0877 - val_loss: 0.0776 - 36ms/epoch - 6ms/step
# Epoch 16/70
# 6/6 - 0s - loss: 0.0877 - val_loss: 0.0766 - 31ms/epoch - 5ms/step
# Epoch 17/70
# 6/6 - 0s - loss: 0.0878 - val_loss: 0.0773 - 39ms/epoch - 7ms/step
# Epoch 18/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0770 - 26ms/epoch - 4ms/step
# Epoch 19/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0766 - 40ms/epoch - 7ms/step
# Epoch 20/70
# 6/6 - 0s - loss: 0.0875 - val_loss: 0.0772 - 27ms/epoch - 5ms/step
# Epoch 21/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0765 - 43ms/epoch - 7ms/step
# Epoch 22/70
# 6/6 - 0s - loss: 0.0876 - val_loss: 0.0767 - 30ms/epoch - 5ms/step
# Epoch 23/70
# 6/6 - 0s - loss: 0.0875 - val_loss: 0.0771 - 34ms/epoch - 6ms/step
# Epoch 24/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0759 - 34ms/epoch - 6ms/step
# Epoch 25/70
# 6/6 - 0s - loss: 0.0876 - val_loss: 0.0770 - 34ms/epoch - 6ms/step
# Epoch 26/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0755 - 34ms/epoch - 6ms/step
# Epoch 27/70
# 6/6 - 0s - loss: 0.0875 - val_loss: 0.0763 - 34ms/epoch - 6ms/step
# Epoch 28/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0758 - 29ms/epoch - 5ms/step
# Epoch 29/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0763 - 26ms/epoch - 4ms/step
# Epoch 30/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0762 - 30ms/epoch - 5ms/step
# Epoch 31/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0760 - 36ms/epoch - 6ms/step
# Epoch 32/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0760 - 40ms/epoch - 7ms/step
# Epoch 33/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0763 - 26ms/epoch - 4ms/step
# Epoch 34/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0748 - 38ms/epoch - 6ms/step
# Epoch 35/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0755 - 30ms/epoch - 5ms/step
# Epoch 36/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0754 - 22ms/epoch - 4ms/step
# Epoch 37/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0757 - 46ms/epoch - 8ms/step
# Epoch 38/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0756 - 33ms/epoch - 6ms/step
# Epoch 39/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0759 - 27ms/epoch - 4ms/step
# Epoch 40/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0753 - 39ms/epoch - 7ms/step
# Epoch 41/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0762 - 27ms/epoch - 4ms/step
# Epoch 42/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0752 - 39ms/epoch - 6ms/step
# Epoch 43/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0759 - 33ms/epoch - 5ms/step
# Epoch 44/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0754 - 32ms/epoch - 5ms/step
# Epoch 45/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0754 - 32ms/epoch - 5ms/step
# Epoch 46/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0756 - 35ms/epoch - 6ms/step
# Epoch 47/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0759 - 23ms/epoch - 4ms/step
# Epoch 48/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0741 - 40ms/epoch - 7ms/step
# Epoch 49/70
# 6/6 - 0s - loss: 0.0877 - val_loss: 0.0763 - 30ms/epoch - 5ms/step
# Epoch 50/70
# 6/6 - 0s - loss: 0.0869 - val_loss: 0.0752 - 28ms/epoch - 5ms/step
# Epoch 51/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0749 - 40ms/epoch - 7ms/step
# Epoch 52/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0755 - 29ms/epoch - 5ms/step
# Epoch 53/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0742 - 43ms/epoch - 7ms/step
# Epoch 54/70
# 6/6 - 0s - loss: 0.0875 - val_loss: 0.0762 - 34ms/epoch - 6ms/step
# Epoch 55/70
# 6/6 - 0s - loss: 0.0869 - val_loss: 0.0754 - 34ms/epoch - 6ms/step
# Epoch 56/70
# 6/6 - 0s - loss: 0.0870 - val_loss: 0.0745 - 37ms/epoch - 6ms/step
# Epoch 57/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0753 - 34ms/epoch - 6ms/step
# Epoch 58/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0756 - 32ms/epoch - 5ms/step
# Epoch 59/70
# 6/6 - 0s - loss: 0.0870 - val_loss: 0.0757 - 35ms/epoch - 6ms/step
# Epoch 60/70
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0747 - 34ms/epoch - 6ms/step
# Epoch 61/70
# 6/6 - 0s - loss: 0.0873 - val_loss: 0.0759 - 32ms/epoch - 5ms/step
# Epoch 62/70
# 6/6 - 0s - loss: 0.0870 - val_loss: 0.0747 - 35ms/epoch - 6ms/step
# Epoch 63/70
# 6/6 - 0s - loss: 0.0872 - val_loss: 0.0757 - 34ms/epoch - 6ms/step
# Epoch 64/70
# 6/6 - 0s - loss: 0.0870 - val_loss: 0.0753 - 35ms/epoch - 6ms/step
# Epoch 65/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0758 - 45ms/epoch - 8ms/step
# Epoch 66/70
# 6/6 - 0s - loss: 0.0871 - val_loss: 0.0760 - 37ms/epoch - 6ms/step
# Epoch 67/70
# 6/6 - 0s - loss: 0.0869 - val_loss: 0.0752 - 26ms/epoch - 4ms/step
# Epoch 68/70
# 6/6 - 0s - loss: 0.0877 - val_loss: 0.0738 - 38ms/epoch - 6ms/step
# Epoch 69/70
# 6/6 - 0s - loss: 0.0875 - val_loss: 0.0755 - 28ms/epoch - 5ms/step
# Epoch 70/70
# 6/6 - 0s - loss: 0.0870 - val_loss: 0.0742 - 38ms/epoch - 6ms/step

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
final_predictions = model.predict(test_X)
print(final_predictions.shape)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# (99, 1)

# %%
train_predictions = model.predict(train_X)
print(train_predictions.shape)
# Out:
# 13/13 [==============================] - 0s 987us/step
# (392, 1)

# %%
evaluation_metrics = calculate_evaluation_metrics(test_y, final_predictions)
print(evaluation_metrics)
# Out:
# {'ME': 0.0042732013, 'MAE': 0.07423367, 'MSE': 0.0093133785, 'RMSE': 0.09650585, 'NRMSE': 0.1030095, 'PBIAS': 0.8360146, 'RSR': 0.42097875, 'rSD': 1.3515865, 'NSE': -179.88621520996094, 'mNSE': -179.88621520996094, 'rNSE': -3423.031662156531, 'd': 0.4172106981277466, 'md': 0.4172106981277466, 'rd': 0.4172106981277466, 'cp': 0.4172106981277466, 'r': 0.4172106981277466, 'R2': 0.8227769221165018}

# %%
import pandas as pd
pd.DataFrame(train_y).to_csv('actualTrainRNN .csv', index=False, header=False)
pd.DataFrame(train_predictions).to_csv('predictTrainRNN.csv', index=False, header=False)
pd.DataFrame(test_y).to_csv('actualTestRNN.csv', index=False, header=False)
pd.DataFrame(final_predictions).to_csv('predictTestRNN.csv', index=False, header=False)

# %% [markdown]
# # LSTM

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=80, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/80
# 6/6 - 2s - loss: 0.5846 - val_loss: 0.5629 - 2s/epoch - 340ms/step
# Epoch 2/80
# 6/6 - 0s - loss: 0.5264 - val_loss: 0.5045 - 44ms/epoch - 7ms/step
# Epoch 3/80
# 6/6 - 0s - loss: 0.4682 - val_loss: 0.4453 - 40ms/epoch - 7ms/step
# Epoch 4/80
# 6/6 - 0s - loss: 0.4121 - val_loss: 0.3870 - 37ms/epoch - 6ms/step
# Epoch 5/80
# 6/6 - 0s - loss: 0.3615 - val_loss: 0.3300 - 37ms/epoch - 6ms/step
# Epoch 6/80
# 6/6 - 0s - loss: 0.3168 - val_loss: 0.2757 - 37ms/epoch - 6ms/step
# Epoch 7/80
# 6/6 - 0s - loss: 0.2783 - val_loss: 0.2277 - 40ms/epoch - 7ms/step
# Epoch 8/80
# 6/6 - 0s - loss: 0.2452 - val_loss: 0.1881 - 35ms/epoch - 6ms/step
# Epoch 9/80
# 6/6 - 0s - loss: 0.2210 - val_loss: 0.1611 - 43ms/epoch - 7ms/step
# Epoch 10/80
# 6/6 - 0s - loss: 0.2034 - val_loss: 0.1465 - 38ms/epoch - 6ms/step
# Epoch 11/80
# 6/6 - 0s - loss: 0.1938 - val_loss: 0.1416 - 39ms/epoch - 6ms/step
# Epoch 12/80
# 6/6 - 0s - loss: 0.1891 - val_loss: 0.1400 - 37ms/epoch - 6ms/step
# Epoch 13/80
# 6/6 - 0s - loss: 0.1860 - val_loss: 0.1378 - 38ms/epoch - 6ms/step
# Epoch 14/80
# 6/6 - 0s - loss: 0.1823 - val_loss: 0.1344 - 37ms/epoch - 6ms/step
# Epoch 15/80
# 6/6 - 0s - loss: 0.1782 - val_loss: 0.1304 - 39ms/epoch - 6ms/step
# Epoch 16/80
# 6/6 - 0s - loss: 0.1742 - val_loss: 0.1269 - 40ms/epoch - 7ms/step
# Epoch 17/80
# 6/6 - 0s - loss: 0.1702 - val_loss: 0.1235 - 27ms/epoch - 5ms/step
# Epoch 18/80
# 6/6 - 0s - loss: 0.1662 - val_loss: 0.1200 - 34ms/epoch - 6ms/step
# Epoch 19/80
# 6/6 - 0s - loss: 0.1621 - val_loss: 0.1165 - 38ms/epoch - 6ms/step
# Epoch 20/80
# 6/6 - 0s - loss: 0.1578 - val_loss: 0.1129 - 37ms/epoch - 6ms/step
# Epoch 21/80
# 6/6 - 0s - loss: 0.1537 - val_loss: 0.1094 - 50ms/epoch - 8ms/step
# Epoch 22/80
# 6/6 - 0s - loss: 0.1495 - val_loss: 0.1060 - 39ms/epoch - 6ms/step
# Epoch 23/80
# 6/6 - 0s - loss: 0.1452 - val_loss: 0.1027 - 37ms/epoch - 6ms/step
# Epoch 24/80
# 6/6 - 0s - loss: 0.1409 - val_loss: 0.0993 - 38ms/epoch - 6ms/step
# Epoch 25/80
# 6/6 - 0s - loss: 0.1364 - val_loss: 0.0959 - 38ms/epoch - 6ms/step
# Epoch 26/80
# 6/6 - 0s - loss: 0.1321 - val_loss: 0.0922 - 38ms/epoch - 6ms/step
# Epoch 27/80
# 6/6 - 0s - loss: 0.1278 - val_loss: 0.0886 - 40ms/epoch - 7ms/step
# Epoch 28/80
# 6/6 - 0s - loss: 0.1235 - val_loss: 0.0852 - 38ms/epoch - 6ms/step
# Epoch 29/80
# 6/6 - 0s - loss: 0.1193 - val_loss: 0.0821 - 42ms/epoch - 7ms/step
# Epoch 30/80
# 6/6 - 0s - loss: 0.1151 - val_loss: 0.0800 - 40ms/epoch - 7ms/step
# Epoch 31/80
# 6/6 - 0s - loss: 0.1112 - val_loss: 0.0782 - 40ms/epoch - 7ms/step
# Epoch 32/80
# 6/6 - 0s - loss: 0.1075 - val_loss: 0.0760 - 39ms/epoch - 7ms/step
# Epoch 33/80
# 6/6 - 0s - loss: 0.1040 - val_loss: 0.0751 - 39ms/epoch - 6ms/step
# Epoch 34/80
# 6/6 - 0s - loss: 0.1009 - val_loss: 0.0748 - 33ms/epoch - 5ms/step
# Epoch 35/80
# 6/6 - 0s - loss: 0.0980 - val_loss: 0.0738 - 44ms/epoch - 7ms/step
# Epoch 36/80
# 6/6 - 0s - loss: 0.0955 - val_loss: 0.0729 - 38ms/epoch - 6ms/step
# Epoch 37/80
# 6/6 - 0s - loss: 0.0936 - val_loss: 0.0731 - 39ms/epoch - 7ms/step
# Epoch 38/80
# 6/6 - 0s - loss: 0.0920 - val_loss: 0.0734 - 40ms/epoch - 7ms/step
# Epoch 39/80
# 6/6 - 0s - loss: 0.0905 - val_loss: 0.0737 - 39ms/epoch - 6ms/step
# Epoch 40/80
# 6/6 - 0s - loss: 0.0895 - val_loss: 0.0744 - 37ms/epoch - 6ms/step
# Epoch 41/80
# 6/6 - 0s - loss: 0.0885 - val_loss: 0.0752 - 38ms/epoch - 6ms/step
# Epoch 42/80
# 6/6 - 0s - loss: 0.0878 - val_loss: 0.0760 - 38ms/epoch - 6ms/step
# Epoch 43/80
# 6/6 - 0s - loss: 0.0874 - val_loss: 0.0766 - 40ms/epoch - 7ms/step
# Epoch 44/80
# 6/6 - 0s - loss: 0.0870 - val_loss: 0.0769 - 39ms/epoch - 7ms/step
# Epoch 45/80
# 6/6 - 0s - loss: 0.0869 - val_loss: 0.0774 - 41ms/epoch - 7ms/step
# Epoch 46/80
# 6/6 - 0s - loss: 0.0868 - val_loss: 0.0778 - 41ms/epoch - 7ms/step
# Epoch 47/80
# 6/6 - 0s - loss: 0.0868 - val_loss: 0.0784 - 32ms/epoch - 5ms/step
# Epoch 48/80
# 6/6 - 0s - loss: 0.0865 - val_loss: 0.0786 - 44ms/epoch - 7ms/step
# Epoch 49/80
# 6/6 - 0s - loss: 0.0864 - val_loss: 0.0784 - 35ms/epoch - 6ms/step
# Epoch 50/80
# 6/6 - 0s - loss: 0.0865 - val_loss: 0.0787 - 39ms/epoch - 6ms/step
# Epoch 51/80
# 6/6 - 0s - loss: 0.0864 - val_loss: 0.0789 - 39ms/epoch - 7ms/step
# Epoch 52/80
# 6/6 - 0s - loss: 0.0862 - val_loss: 0.0786 - 40ms/epoch - 7ms/step
# Epoch 53/80
# 6/6 - 0s - loss: 0.0864 - val_loss: 0.0788 - 39ms/epoch - 7ms/step
# Epoch 54/80
# 6/6 - 0s - loss: 0.0863 - val_loss: 0.0789 - 41ms/epoch - 7ms/step
# Epoch 55/80
# 6/6 - 0s - loss: 0.0862 - val_loss: 0.0788 - 37ms/epoch - 6ms/step
# Epoch 56/80
# 6/6 - 0s - loss: 0.0862 - val_loss: 0.0789 - 38ms/epoch - 6ms/step
# Epoch 57/80
# 6/6 - 0s - loss: 0.0862 - val_loss: 0.0790 - 37ms/epoch - 6ms/step
# Epoch 58/80
# 6/6 - 0s - loss: 0.0861 - val_loss: 0.0789 - 37ms/epoch - 6ms/step
# Epoch 59/80
# 6/6 - 0s - loss: 0.0861 - val_loss: 0.0789 - 36ms/epoch - 6ms/step
# Epoch 60/80
# 6/6 - 0s - loss: 0.0861 - val_loss: 0.0789 - 35ms/epoch - 6ms/step
# Epoch 61/80
# 6/6 - 0s - loss: 0.0860 - val_loss: 0.0788 - 39ms/epoch - 7ms/step
# Epoch 62/80
# 6/6 - 0s - loss: 0.0860 - val_loss: 0.0786 - 37ms/epoch - 6ms/step
# Epoch 63/80
# 6/6 - 0s - loss: 0.0860 - val_loss: 0.0785 - 37ms/epoch - 6ms/step
# Epoch 64/80
# 6/6 - 0s - loss: 0.0860 - val_loss: 0.0784 - 37ms/epoch - 6ms/step
# Epoch 65/80
# 6/6 - 0s - loss: 0.0859 - val_loss: 0.0783 - 39ms/epoch - 6ms/step
# Epoch 66/80
# 6/6 - 0s - loss: 0.0859 - val_loss: 0.0782 - 34ms/epoch - 6ms/step
# Epoch 67/80
# 6/6 - 0s - loss: 0.0859 - val_loss: 0.0781 - 34ms/epoch - 6ms/step
# Epoch 68/80
# 6/6 - 0s - loss: 0.0859 - val_loss: 0.0782 - 37ms/epoch - 6ms/step
# Epoch 69/80
# 6/6 - 0s - loss: 0.0859 - val_loss: 0.0782 - 37ms/epoch - 6ms/step
# Epoch 70/80
# 6/6 - 0s - loss: 0.0858 - val_loss: 0.0782 - 37ms/epoch - 6ms/step
# Epoch 71/80
# 6/6 - 0s - loss: 0.0858 - val_loss: 0.0780 - 37ms/epoch - 6ms/step
# Epoch 72/80
# 6/6 - 0s - loss: 0.0858 - val_loss: 0.0780 - 40ms/epoch - 7ms/step
# Epoch 73/80
# 6/6 - 0s - loss: 0.0858 - val_loss: 0.0780 - 38ms/epoch - 6ms/step
# Epoch 74/80
# 6/6 - 0s - loss: 0.0858 - val_loss: 0.0779 - 33ms/epoch - 5ms/step
# Epoch 75/80
# 6/6 - 0s - loss: 0.0857 - val_loss: 0.0779 - 33ms/epoch - 6ms/step
# Epoch 76/80
# 6/6 - 0s - loss: 0.0857 - val_loss: 0.0779 - 39ms/epoch - 6ms/step
# Epoch 77/80
# 6/6 - 0s - loss: 0.0857 - val_loss: 0.0779 - 38ms/epoch - 6ms/step
# Epoch 78/80
# 6/6 - 0s - loss: 0.0857 - val_loss: 0.0778 - 38ms/epoch - 6ms/step
# Epoch 79/80
# 6/6 - 0s - loss: 0.0857 - val_loss: 0.0777 - 35ms/epoch - 6ms/step
# Epoch 80/80
# 6/6 - 0s - loss: 0.0856 - val_loss: 0.0776 - 34ms/epoch - 6ms/step

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
final_predictions = model.predict(test_X)
print(final_predictions.shape)
# Out:
# 4/4 [==============================] - 0s 5ms/step
# (99, 1)

# %%
train_predictions = model.predict(train_X)
print(train_predictions.shape)
# Out:
# 13/13 [==============================] - 0s 2ms/step
# (392, 1)

# %%
import pandas as pd
pd.DataFrame(train_y).to_csv('actualTrainLSTM .csv', index=False, header=False)
pd.DataFrame(train_predictions).to_csv('predictTrainLSTM .csv', index=False, header=False)
pd.DataFrame(test_y).to_csv('actualTestLSTM.csv', index=False, header=False)
pd.DataFrame(final_predictions).to_csv('predictTestLSTM.csv', index=False, header=False)

# %%
evaluation_metrics = calculate_evaluation_metrics(test_y, final_predictions)
print(evaluation_metrics)
# Out:
# {'ME': 0.010110961, 'MAE': 0.07763915, 'MSE': 0.010243948, 'RMSE': 0.10121239, 'NRMSE': 0.10803322, 'PBIAS': 1.9781204, 'RSR': 0.44150966, 'rSD': 1.363923, 'NSE': -183.3609161376953, 'mNSE': -183.3609161376953, 'rNSE': -3489.1512993854144, 'd': 0.41870349645614624, 'md': 0.41870349645614624, 'rd': 0.41870349645614624, 'cp': 0.41870349645614624, 'r': 0.41870349645614624, 'R2': 0.8050692226721903}

# %% [markdown]
# # GRU

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense

# Design network
model = Sequential()
model.add(GRU(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# Fit network
history = model.fit(train_X, train_y, epochs=80, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/80

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
final_predictions = model.predict(test_X)
print(final_predictions.shape)

# %%
train_predictions = model.predict(train_X)
print(train_predictions.shape)

# %%
pd.DataFrame(train_y).to_csv('actualTrainGRU .csv', index=False, header=False)
pd.DataFrame(train_predictions).to_csv('predictTrainGRU.csv', index=False, header=False)
pd.DataFrame(test_y).to_csv('actualTestGRU.csv', index=False, header=False)
pd.DataFrame(final_predictions).to_csv('predictTestGRU.csv', index=False, header=False)

# %%
evaluation_metrics = calculate_evaluation_metrics(test_y, final_predictions)
print(evaluation_metrics)
